# %% [markdown]
# # KKBox Dataset Preprocessing

# %%
# Load Python libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing KKBox data

# %%
df_train = pd.read_csv('C:/Users/ekwaning/Documents/Flatiron/Capstone/Capstone-Project/Data/train.csv')
df_train
# Out:
#                                                  msno  \
# 0        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4        FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                               ...
# 7377413  6xdFzPlrasIDD95mQWXVC3Bg4ptnGYtBl4ztVEZMddU=
# 7377414  ZxbVmt3Kh/XOH+h58c2Kdj6SjFZk+wnUO006IgWzMQE=
# 7377415  ZxbVmt3Kh/XOH+h58c2Kdj6SjFZk+wnUO006IgWzMQE=
# 7377416  0aH4Hd3ziPSRHClRX8rkeOEaAG5EPPkW1mKGCdXEok0=
# 7377417  0aH4Hd3ziPSRHClRX8rkeOEaAG5EPPkW1mKGCdXEok0=
#
#                                               song_id source_system_tab  \
# 0        BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1        bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2        JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3        2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4        3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...                                               ...               ...
# 7377413  VJTxizih/o28kXCbtPbIyWXScoXGvxyYtl6R+0YB5JM=        my library
# 7377414  z1mqaU9YOX7T/PFDvUoWozdFq7rC3KwaQP7nFVprjMI=            search
# 7377415  750RprmFfLV0bymtDH88g24pLZGVi5VpBAI300P6UOA=            search
# 7377416  G8wgqObgeAMER/rVCIlgcNeQ8mm0CzF/GsxiMK8TTnA=          discover
# 7377417  Ju0VGkjWeBUZCd7r5Az2hUImhMoWxWLUicOedsmvG0g=          discover
#
#           source_screen_name      source_type  target
# 0                    Explore  online-playlist       1
# 1        Local playlist more   local-playlist       1
# 2        Local playlist more   local-playlist       1
# 3        Local playlist more   local-playlist       1
# 4                    Explore  online-playlist       1
# ...                      ...              ...     ...
# 7377413  Local playlist more   local-playlist       1
# 7377414               Search             song       0
# 7377415               Search             song       1
# 7377416       Discover Genre  online-playlist       1
# 7377417       Discover Genre  online-playlist       1
#
# [7377418 rows x 6 columns]

# %%
df_train = df_train.sample(frac=0.01)
df_train
# Out:
#                                                  msno  \
# 4678673  lCJVKpwOSIUmRbNGm/U5nhQGcFC2ffzCZQF1DaY270U=
# 3451735  f2GqOnq9UbJW9VQosYI5lXgLiEUprFeF2JiXGyXJSgA=
# 4318492  V39VxDdE9SgMQZnX58oQChm9W056pw2lC3TiifMfkKw=
# 5687866  15cWrSkA0gdkrwU4Wzsnb2oWvDT3n77/zYrbtdNPoCY=
# 3516539  v0iILm4BOm8kOjfl6oPzdXvF7aE0uNlB1kX7lk24H5c=
# ...                                               ...
# 1128059  5GokfrtZUvkqYIXHAjjSw611Dlel8it+NWjW/pgo470=
# 3583289  TZ4SbeXfsF1BED4g79hD//GZ4ciX/FoTPF703PJ9UsM=
# 4734445  1fzIKBE+qkgTZ5qShI3CaV6FigMPXciRE5wdAYaW7yM=
# 337730   YelHKBX8Re7wDCDvuNCcz33dqO3wrM8jye3L1lo/Fhw=
# 6375229  6LckLwHjnbFWdYwA1bRTVPFtwUiWiRpmxn+DuYvsQRc=
#
#                                               song_id source_system_tab  \
# 4678673  nxFf702AZs2zkZktQNBMXzdATyA+hI3uFzxHyltNJo4=        my library
# 3451735  VOHBl8rho2+hBAU/PLE4iPsyYTuG7w7uzWmLW3H7TUQ=          discover
# 4318492  ItxKix3BeWJAZIkDMXIL6SHIOyc2M1E2bIBbeyDkoe0=          discover
# 5687866  FKwSc7IYpr376O9kTncp1SXkpJHDguk9cCaTGgQ/4zc=          discover
# 3516539  34IXh04bdV42ClAF+3lHsAjNQEA9yljeyamS6+Wv1BQ=        my library
# ...                                               ...               ...
# 1128059  jfN42n7HnseoX7KLYtrQSgaMCQsc1vObITMjFOa1RFA=        my library
# 3583289  skrrk46A5o7WyOsWUTLTy5bnznOGeJv2/MFgaS8+VUk=        my library
# 4734445  F+Q6TbPeTzry2e70cjzk/9ofEJZad0o4OvXrtE5GW0Q=        my library
# 337730   m/isEYbpDVBeNSY0fPSfhyIbLDKOiWTYMEm631aMPy8=          discover
# 6375229  8yBtb/04vYNbrAfjqSGGLwylKOVyWwV19RYtLROqFRg=          discover
#
#            source_screen_name      source_type  target
# 4678673   Local playlist more    local-library       1
# 3451735          Discover New  online-playlist       1
# 4318492  Online playlist more  online-playlist       1
# 5687866  Online playlist more  online-playlist       0
# 3516539   Local playlist more    local-library       1
# ...                       ...              ...     ...
# 1128059   Local playlist more   local-playlist       1
# 3583289   Local playlist more   local-playlist       1
# 4734445  Online playlist more  online-playlist       0
# 337730         Discover Genre  online-playlist       1
# 6375229        Discover Genre  online-playlist       0
#
# [73774 rows x 6 columns]

# %%
df_songs = pd.read_csv('C:/Users/ekwaning/Documents/Flatiron/Capstone/Capstone-Project/Data/songs.csv')
df_songs.head(10)
# Out:
#                                         song_id  song_length        genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640              465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328              444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781              465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554              465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329              726
# 5  kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520  864|857|850|843
# 6  N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220              458
# 7  GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793              465
# 8  oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623              465
# 9  btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629         352|1995
#
#          artist_name                                           composer  \
# 0   張信哲 (Jeff Chang)                                                 董貞
# 1          BLACKPINK                 TEDDY|  FUTURE BOUNCE|  Bekuh BOOM
# 2       SUPER JUNIOR                                                NaN
# 3              S.H.E                                                湯小康
# 4               貴族精選                                        Traditional
# 5               貴族精選                                       Joe Hisaishi
# 6    伍佰 & China Blue                                       Jonathan Lee
# 7  光良 (Michael Wong)                                                 光良
# 8       林俊傑 (JJ Lin)                                             JJ Lin
# 9           Kodaline  Stephen Garrigan| Mark Prendergast| Vincent Ma...
#
#                                             lyricist  language
# 0                                                何啟弘       3.0
# 1                                              TEDDY      31.0
# 2                                                NaN      31.0
# 3                                                徐世珍       3.0
# 4                                        Traditional      52.0
# 5                                     Hayao Miyazaki      17.0
# 6                                                NaN       3.0
# 7                                                彭資閔       3.0
# 8                                       Wu Qing Feng       3.0
# 9  Stephen Garrigan| Mark Prendergast| Vincent Ma...      52.0

# %%
df_members = pd.read_csv('C:/Users/ekwaning/Documents/Flatiron/Capstone/Capstone-Project/Data/members.csv')
df_members.head(10)
# Out:
#                                            msno  city  bd  gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0     NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0     NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0     NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0     NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0     NaN
# 5  zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=    13  43  female
# 6  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=     1   0     NaN
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=     1   0     NaN
# 8  kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=     1   0     NaN
# 9  tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613
# 5               9                20120703         20171006
# 6               4                20160326         20160329
# 7               7                20160130         20170930
# 8               7                20110111         20170930
# 9               7                20160217         20170613

# %% [markdown]
# Merging Data sets

# %%
#leftjoin songs data to main
df_train = pd.merge(df_train, df_songs, on='song_id', how='left')
df_train.head(10)
# Out:
#                                            msno  \
# 0  lCJVKpwOSIUmRbNGm/U5nhQGcFC2ffzCZQF1DaY270U=
# 1  f2GqOnq9UbJW9VQosYI5lXgLiEUprFeF2JiXGyXJSgA=
# 2  V39VxDdE9SgMQZnX58oQChm9W056pw2lC3TiifMfkKw=
# 3  15cWrSkA0gdkrwU4Wzsnb2oWvDT3n77/zYrbtdNPoCY=
# 4  v0iILm4BOm8kOjfl6oPzdXvF7aE0uNlB1kX7lk24H5c=
# 5  5R+7rrEh/g+AQp3doc+1bHPkdfwR4Md45UOcAKnM3tI=
# 6  48Gi8BYX4SDBf7b3sOOmC0wUahmhK9j3aqeGw3K2dvU=
# 7  P2SS4gSGCxXHOqgXIaHdCGrBeuW23J2OlXZ0vboh8K4=
# 8  xY9ZCBJ5dJO8qWhSaFZLY9wGpJhlQYv6u5c8CjOfMBg=
# 9  6e1beDa3Ro1gSDF9zkk7TvxSQTJ+YIWTKD7jRPmeQBU=
#
#                                         song_id source_system_tab  \
# 0  nxFf702AZs2zkZktQNBMXzdATyA+hI3uFzxHyltNJo4=        my library
# 1  VOHBl8rho2+hBAU/PLE4iPsyYTuG7w7uzWmLW3H7TUQ=          discover
# 2  ItxKix3BeWJAZIkDMXIL6SHIOyc2M1E2bIBbeyDkoe0=          discover
# 3  FKwSc7IYpr376O9kTncp1SXkpJHDguk9cCaTGgQ/4zc=          discover
# 4  34IXh04bdV42ClAF+3lHsAjNQEA9yljeyamS6+Wv1BQ=        my library
# 5  NvXW3FZ9xkipfmuioGgDJ3N1HFd0Kc4km0aomXuCHbk=        my library
# 6  7XjSvrL47/EJD2mNR0e2Ja+ed/Dm0j35tKPQLiO2Hjk=          discover
# 7  pvJlzCEIC4uQ+zcy9LqI7dyt4N0jfY+aLyPNDBLysEA=          discover
# 8  G/ISwM8TU2w83ZvwKhrAewJxtetyFFAgVkc9TsNhfdY=        my library
# 9  lrZ8Flcr2t8azliBFPECv0Ja1D6bOh9k532HNSecoQI=        my library
#
#      source_screen_name      source_type  target  song_length genre_ids  \
# 0   Local playlist more    local-library       1     214970.0       465
# 1          Discover New  online-playlist       1     244480.0       458
# 2  Online playlist more  online-playlist       1     306828.0       465
# 3  Online playlist more  online-playlist       0     299833.0       465
# 4   Local playlist more    local-library       1     344026.0      2022
# 5   Local playlist more    local-library       1     303648.0       458
# 6  Online playlist more  online-playlist       0     273716.0      1609
# 7  Online playlist more  online-playlist       0     303516.0       139
# 8   Local playlist more   local-playlist       1     263360.0      1609
# 9   Local playlist more    local-library       0     215118.0       465
#
#        artist_name                                           composer  \
# 0       Katy Perry  Katy Perry| M Martin| Lukasz Gottwald| Bonnie ...
# 1        Crispy脆樂團                                          Skippy Lu
# 2  Luther Vandross                                                NaN
# 3  林憶蓮 (Sandy Lam)                                      Chen Chi Yuan
# 4         RADWIMPS                                        Yojiro Noda
# 5   亦帆 (Canace Wu)                                                方文良
# 6       Marshmello                                                NaN
# 7         Fantasia                                           R. Kelly
# 8     Maxi Kingdom                                                NaN
# 9        皮諾丘 電視原聲帶                        Oh Chang-hoon| Park Sung-ho
#
#              lyricist  language
# 0                 NaN      52.0
# 1           Skippy Lu       3.0
# 2                 NaN      52.0
# 3       Ding Xiao Wen       3.0
# 4                 NaN      17.0
# 5                  十方       3.0
# 6                 NaN      52.0
# 7            R. Kelly      52.0
# 8                 NaN      52.0
# 9  Ji-hoon| Koo Ji-an      31.0

# %%
#leftjoin members data to main
df_train = pd.merge(df_train, df_members, on='msno', how='left')
df_train.head(10)
# Out:
#                                            msno  \
# 0  lCJVKpwOSIUmRbNGm/U5nhQGcFC2ffzCZQF1DaY270U=
# 1  f2GqOnq9UbJW9VQosYI5lXgLiEUprFeF2JiXGyXJSgA=
# 2  V39VxDdE9SgMQZnX58oQChm9W056pw2lC3TiifMfkKw=
# 3  15cWrSkA0gdkrwU4Wzsnb2oWvDT3n77/zYrbtdNPoCY=
# 4  v0iILm4BOm8kOjfl6oPzdXvF7aE0uNlB1kX7lk24H5c=
# 5  5R+7rrEh/g+AQp3doc+1bHPkdfwR4Md45UOcAKnM3tI=
# 6  48Gi8BYX4SDBf7b3sOOmC0wUahmhK9j3aqeGw3K2dvU=
# 7  P2SS4gSGCxXHOqgXIaHdCGrBeuW23J2OlXZ0vboh8K4=
# 8  xY9ZCBJ5dJO8qWhSaFZLY9wGpJhlQYv6u5c8CjOfMBg=
# 9  6e1beDa3Ro1gSDF9zkk7TvxSQTJ+YIWTKD7jRPmeQBU=
#
#                                         song_id source_system_tab  \
# 0  nxFf702AZs2zkZktQNBMXzdATyA+hI3uFzxHyltNJo4=        my library
# 1  VOHBl8rho2+hBAU/PLE4iPsyYTuG7w7uzWmLW3H7TUQ=          discover
# 2  ItxKix3BeWJAZIkDMXIL6SHIOyc2M1E2bIBbeyDkoe0=          discover
# 3  FKwSc7IYpr376O9kTncp1SXkpJHDguk9cCaTGgQ/4zc=          discover
# 4  34IXh04bdV42ClAF+3lHsAjNQEA9yljeyamS6+Wv1BQ=        my library
# 5  NvXW3FZ9xkipfmuioGgDJ3N1HFd0Kc4km0aomXuCHbk=        my library
# 6  7XjSvrL47/EJD2mNR0e2Ja+ed/Dm0j35tKPQLiO2Hjk=          discover
# 7  pvJlzCEIC4uQ+zcy9LqI7dyt4N0jfY+aLyPNDBLysEA=          discover
# 8  G/ISwM8TU2w83ZvwKhrAewJxtetyFFAgVkc9TsNhfdY=        my library
# 9  lrZ8Flcr2t8azliBFPECv0Ja1D6bOh9k532HNSecoQI=        my library
#
#      source_screen_name      source_type  target  song_length genre_ids  \
# 0   Local playlist more    local-library       1     214970.0       465
# 1          Discover New  online-playlist       1     244480.0       458
# 2  Online playlist more  online-playlist       1     306828.0       465
# 3  Online playlist more  online-playlist       0     299833.0       465
# 4   Local playlist more    local-library       1     344026.0      2022
# 5   Local playlist more    local-library       1     303648.0       458
# 6  Online playlist more  online-playlist       0     273716.0      1609
# 7  Online playlist more  online-playlist       0     303516.0       139
# 8   Local playlist more   local-playlist       1     263360.0      1609
# 9   Local playlist more    local-library       0     215118.0       465
#
#        artist_name                                           composer  \
# 0       Katy Perry  Katy Perry| M Martin| Lukasz Gottwald| Bonnie ...
# 1        Crispy脆樂團                                          Skippy Lu
# 2  Luther Vandross                                                NaN
# 3  林憶蓮 (Sandy Lam)                                      Chen Chi Yuan
# 4         RADWIMPS                                        Yojiro Noda
# 5   亦帆 (Canace Wu)                                                方文良
# 6       Marshmello                                                NaN
# 7         Fantasia                                           R. Kelly
# 8     Maxi Kingdom                                                NaN
# 9        皮諾丘 電視原聲帶                        Oh Chang-hoon| Park Sung-ho
#
#              lyricist  language  city  bd  gender  registered_via  \
# 0                 NaN      52.0    13  18    male               7
# 1           Skippy Lu       3.0    22  37    male               3
# 2                 NaN      52.0    14   0     NaN               4
# 3       Ding Xiao Wen       3.0     5  21  female               9
# 4                 NaN      17.0     5  24  female               9
# 5                  十方       3.0     3  18    male               9
# 6                 NaN      52.0     1   0     NaN               4
# 7            R. Kelly      52.0    15  29     NaN               4
# 8                 NaN      52.0     1   0     NaN               7
# 9  Ji-hoon| Koo Ji-an      31.0     5   0     NaN               4
#
#    registration_init_time  expiration_date
# 0                20160904         20171006
# 1                20130525         20171002
# 2                20160213         20180517
# 3                20080607         20171002
# 4                20111208         20171126
# 5                20150329         20170911
# 6                20170110         20170113
# 7                20151010         20170909
# 8                20110518         20170327
# 9                20160301         20170915

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73774 entries, 0 to 73773
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   msno                    73774 non-null  object
#  1   song_id                 73774 non-null  object
#  2   source_system_tab       73542 non-null  object
#  3   source_screen_name      69612 non-null  object
#  4   source_type             73572 non-null  object
#  5   target                  73774 non-null  int64
#  6   song_length             73773 non-null  float64
#  7   genre_ids               72634 non-null  object
#  8   artist_name             73773 non-null  object
#  9   composer                57061 non-null  object
#  10  lyricist                41850 non-null  object
#  11  language                73773 non-null  float64
#  12  city                    73774 non-null  int64
#  13  bd                      73774 non-null  int64
#  14  gender                  43930 non-null  object
#  15  registered_via          73774 non-null  int64
#  16  registration_init_time  73774 non-null  int64
#  17  expiration_date         73774 non-null  int64
# dtypes: float64(2), int64(6), object(10)
# memory usage: 10.7+ MB

# %% [markdown]
# Missing Data values

# %%
# Count Na in %
df_train.isnull().sum()/df_train.isnull().count()*100
# Out:
# msno                       0.000000
# song_id                    0.000000
# source_system_tab          0.314474
# source_screen_name         5.641554
# source_type                0.273809
# target                     0.000000
# song_length                0.001355
# genre_ids                  1.545260
# artist_name                0.001355
# composer                  22.654323
# lyricist                  43.272698
# language                   0.001355
# city                       0.000000
# bd                         0.000000
# gender                    40.453276
# registered_via             0.000000
# registration_init_time     0.000000
# expiration_date            0.000000
# dtype: float64

# %%
# Replace NA
for i in df_train.select_dtypes(include=['object']).columns:
    df_train[i][df_train[i].isnull()] = 'unknown'
df_train = df_train.fillna(value=0)

# %%
# Count Na in %
df_train.isnull().sum()/df_train.isnull().count()*100
# Out:
# msno                      0.0
# song_id                   0.0
# source_system_tab         0.0
# source_screen_name        0.0
# source_type               0.0
# target                    0.0
# song_length               0.0
# genre_ids                 0.0
# artist_name               0.0
# composer                  0.0
# lyricist                  0.0
# language                  0.0
# city                      0.0
# bd                        0.0
# gender                    0.0
# registered_via            0.0
# registration_init_time    0.0
# expiration_date           0.0
# dtype: float64

# %% [markdown]
# Format Dates

# %%
# Create Dates

# registration_init_time
df_train.registration_init_time = pd.to_datetime(df_train.registration_init_time, format='%Y%m%d', errors='ignore')
df_train['registration_init_time_year'] = df_train['registration_init_time'].dt.year
df_train['registration_init_time_month'] = df_train['registration_init_time'].dt.month
df_train['registration_init_time_day'] = df_train['registration_init_time'].dt.day

# expiration_date
df_train.expiration_date = pd.to_datetime(df_train.expiration_date,  format='%Y%m%d', errors='ignore')
df_train['expiration_date_year'] = df_train['expiration_date'].dt.year
df_train['expiration_date_month'] = df_train['expiration_date'].dt.month
df_train['expiration_date_day'] = df_train['expiration_date'].dt.day

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73774 entries, 0 to 73773
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   msno                          73774 non-null  object
#  1   song_id                       73774 non-null  object
#  2   source_system_tab             73774 non-null  object
#  3   source_screen_name            73774 non-null  object
#  4   source_type                   73774 non-null  object
#  5   target                        73774 non-null  int64
#  6   song_length                   73774 non-null  float64
#  7   genre_ids                     73774 non-null  object
#  8   artist_name                   73774 non-null  object
#  9   composer                      73774 non-null  object
#  10  lyricist                      73774 non-null  object
#  11  language                      73774 non-null  float64
#  12  city                          73774 non-null  int64
#  13  bd                            73774 non-null  int64
#  14  gender                        73774 non-null  object
#  15  registered_via                73774 non-null  int64
#  16  registration_init_time        73774 non-null  datetime64[ns]
#  17  expiration_date               73774 non-null  datetime64[ns]
#  18  registration_init_time_year   73774 non-null  int64
#  19  registration_init_time_month  73774 non-null  int64
#  20  registration_init_time_day    73774 non-null  int64
#  21  expiration_date_year          73774 non-null  int64
#  22  expiration_date_month         73774 non-null  int64
#  23  expiration_date_day           73774 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(10), object(10)
# memory usage: 14.1+ MB

# %%
# Dates to category
df_train['registration_init_time'] = df_train['registration_init_time'].astype('category')
df_train['expiration_date'] = df_train['expiration_date'].astype('category')

# %%
# Object data to category
for col in df_train.select_dtypes(include=['object']).columns:
    df_train[col] = df_train[col].astype('category')
    
# Encoding categorical features
for col in df_train.select_dtypes(include=['category']).columns:
    df_train[col] = df_train[col].cat.codes

# %%
df_train.head()
# Out:
#     msno  song_id  source_system_tab  source_screen_name  source_type  target  \
# 0  14468    22272                  3                   7            3       1
# 1  12717    14354                  0                   5            6       1
# 2   9678     9044                  0                  10            6       1
# 3    913     7515                  0                  10            6       0
# 4  17467     2188                  3                   7            3       1
#
#    song_length  genre_ids  artist_name  composer  ...  gender  registered_via  \
# 0     214970.0        140         2237      3983  ...       1               7
# 1     244480.0        137          966      6439  ...       1               3
# 2     306828.0        140         2572      7715  ...       2               4
# 3     299833.0        140         5516      1209  ...       0               9
# 4     344026.0         69         3321      7457  ...       0               9
#
#    registration_init_time  expiration_date  registration_init_time_year  \
# 0                    3456              613                         2016
# 1                    2326              609                         2013
# 2                    3318              835                         2016
# 3                     890              609                         2008
# 4                    1910              664                         2011
#
#    registration_init_time_month  registration_init_time_day  \
# 0                             9                           4
# 1                             5                          25
# 2                             2                          13
# 3                             6                           7
# 4                            12                           8
#
#    expiration_date_year  expiration_date_month  expiration_date_day
# 0                  2017                     10                    6
# 1                  2017                     10                    2
# 2                  2018                      5                   17
# 3                  2017                     10                    2
# 4                  2017                     11                   26
#
# [5 rows x 24 columns]

# %%
df_train.to_csv(r'C:/Users/ekwaning/Documents/Flatiron/Capstone/Capstone-Project/Data/train_1.csv')
